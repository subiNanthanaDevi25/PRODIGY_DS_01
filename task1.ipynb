# %% [markdown]
# . Task 1

# %%
#importing necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#reading csv file

df=pd.read_csv("dataset.csv")

#checking top elements
df.head(5)

#checking bottom elements
df.tail(5)

#checking columns
df.columns


df.info()
df.describe()

df.duplicated().sum()

#missing values
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Age_Group   36 non-null     object
#  1   Gender      36 non-null     object
#  2   Population  36 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 996.0+ bytes
# Age_Group     0
# Gender        0
# Population    0
# dtype: int64

# %% [markdown]
# BAR PLOT

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset from a CSV file
file_path = 'dataset.csv'
data = pd.read_csv(file_path)

# Plot the distribution of population by age group and gender using a bar chart
plt.figure(figsize=(12, 6))

# Loop over genders and plot each one separately
for gender in data['Gender'].unique():
    # Filter data by gender
    gender_data = data[data['Gender'] == gender]
    # Create a bar chart for each gender's population distribution across age groups
    plt.bar(gender_data['Age_Group'], gender_data['Population'], alpha=0.6, label=gender)

# Add titles and labels
plt.title('Population Distribution by Age Group and Gender')
plt.xlabel('Age Group')
plt.ylabel('Population')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend(title='Gender')
plt.tight_layout()  # Adjust layout to fit everything nicely

# Show the plot
plt.show()
